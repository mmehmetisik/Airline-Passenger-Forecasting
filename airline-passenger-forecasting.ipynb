# %% [markdown]
# <div style="border: 2px solid #DAA520; padding: 20px; border-radius: 15px; background-color: #F5F5DC; font-family: Arial, sans-serif;">
#     <h2 style="text-align: center; color: #DAA520;"><i class="fas fa-plane"></i> Airline Passenger Forecasting</h2>
#     <p>📈 <strong>Time series analysis</strong> is a comprehensive set of statistical techniques used to analyze the observations of a variable that changes over time, often ordered chronologically. This analysis is utilized to predict future values, identify patterns like seasonality, and understand the components of the time series.</p>
#     <p>✈️ <strong>Airline passenger forecasting</strong> is one of the most common applications of such analyses. In the airline industry, understanding how demand fluctuates over time due to seasonal variations, economic conditions, holidays, and other factors is of critical importance. This is vital for airlines in terms of resource planning, pricing strategies, and operational efficiency.</p>
#     <p>🔍 In this study, we will delve deep into the time series analysis conducted for "Airline Passenger Forecasting" and explore the best practices and techniques in this domain.</p>
# </div>

# %% [markdown]
# ![](https://www.financialexpress.com/wp-content/uploads/2020/02/airport.jpg)

# %% [markdown]
# <div style="background-color: #f9e6e0; padding: 40px; border-radius: 20px; box-shadow: 0 0 25px rgba(0,0,0,0.1); font-family: 'Georgia', serif; line-height: 1.6; border: 4px solid #e67e22;">
#
# <h3 style="text-align: center; color: #d35400; font-size: 1.8em; border-bottom: 2px solid #e74c3c; padding-bottom: 5px; margin-bottom: 20px;">📉 Understanding the Smoothing Method</h3>
#
# <p style="font-size: 1.2em; color: #7f8c8d; margin-top: 20px;">The concept of the smoothing method revolves around refining time series data for better analysis and forecasting. Its core function is to minimize the data noise, emphasizing the principal trend or pattern, which is crucial for deriving insightful and accurate predictions.</p>
#
# <h4 style="color: #2c3e50; font-size: 1.6em; margin-top: 30px; border-left: 5px solid #e74c3c; padding-left: 15px;">📘 Categories of Smoothing Methods</h4>
#
# <ul style="list-style-type: none; padding: 0; margin-top: 15px; font-size: 1.1em;">
#     <li style="padding: 8px 0; color: #8e44ad;"><strong>Moving Average Approach:</strong> In this method, a specific window width is selected. The average of the data points within this window forms a new data point. The window then slides over the dataset, calculating moving averages throughout.</li>
#     <li style="padding: 8px 0; color: #8e44ad;"><strong>Technique of Exponential Smoothing:</strong> Predictions are created by obtaining the weighted average of previous data points. Here, the latest data is assigned more significance, while older data is given less. It operates on the premise that data has a stronger connection with its recent past.</li>
#     <li style="padding: 8px 0; color: #8e44ad;"><strong>Exponential Smoothing Subcategories:</strong> The technique of exponential smoothing further branches out into Single, Double, and Triple Exponential Smoothing. They serve to model different components like level, trend, and seasonality present in the dataset.</li>
# </ul>
#
# <p style="font-size: 1.2em; color: #7f8c8d; margin-top: 20px; border-top: 2px dashed #95a5a6; padding-top: 20px;">🌍 In domains like stock trading, power usage, and meteorological predictions, smoothing methods are widely adopted.</p>
#
# </div>

# %% [markdown]
# <div style="background-color: #e8f1f5; padding: 40px; border-radius: 25px; box-shadow: 0 0 20px rgba(0,0,0,0.07); font-family: 'Verdana', sans-serif; line-height: 1.7; border: 3px solid #bed2d7;">
#
# <h2 style="text-align: center; color: #1a434f; font-size: 2.1em; border-bottom: 3px dotted #3498db; padding-bottom: 15px; margin-bottom: 35px;">📊 Diving into Exponential Smoothing</h2>
#
# <h3 style="color: #2c8e99; font-size: 1.85em; margin-top: 30px;">📘 Single Exponential Smoothing (SES)</h3>
# <ul style="font-size: 1.2em; color: #2e4057; margin-top: 25px;">
#     <li>Best suited for stationary series without trends or seasonality.</li>
#     <li>It primarily models the 'Level' component, akin to the series average.</li>
#     <li>Predictions lean more towards recent past data, using it as the weighted foundation.</li>
#     <li>An ideal method for trend-less, non-seasonal series.</li>
# </ul>
#
# <h3 style="color: #2c8e99; font-size: 1.85em; margin-top: 35px;">📗 Double Exponential Smoothing (DES)</h3>
# <ul style="font-size: 1.2em; color: #2e4057; margin-top: 25px;">
#     <li>Capable of modeling both 'Level' and 'Trend' components, excluding seasonality.</li>
#     <li>An evolution to SES, encompassing the trending aspect of series.</li>
# </ul>
#
# <h3 style="color: #2c8e99; font-size: 1.85em; margin-top: 35px;">📙 Triple Exponential Smoothing (TES - Holt-Winters)</h3>
# <ul style="font-size: 1.2em; color: #2e4057; margin-top: 25px;">
#     <li>The pinnacle of exponential smoothing techniques.</li>
#     <li>It holistically models 'Level', 'Trend', and 'Seasonality' components.</li>
#     <li>Adaptable to both stationary series and those exhibiting trends or seasonality.</li>
# </ul>
#
# <h4 style="text-align: center; color: #e67e22; font-size: 1.7em; margin-top: 45px; border-top: 2px solid #b4c0c7; padding-top: 20px;">🔍 Picking the Right Method</h4>
# <p style="font-size: 1.2em; color: #2e4057; margin-top: 25px;">The key is to opt for the method showcasing the most promising results for the dataset, gauged by its performance metrics.</p>
#
# </div>

# %% [markdown]
# <div style="background-color: #f4f4f4; padding: 20px; border-radius: 20px; box-shadow: 0 0 25px rgba(0,0,0,0.1); font-family: Arial, sans-serif; line-height: 1.6; border: 5px solid #3498db;">
# <h2 style="text-align: center; color: #2c3e50; font-size: 2em; border-bottom: 3px double #2980b9; padding-bottom: 15px; margin-bottom: 30px;">📈 Components of a Time Series</h2>
# </div>

# %% [markdown]
# <div style="background-color: #f4f4f4; padding: 20px; border-radius: 20px; box-shadow: 0 0 25px rgba(0,0,0,0.1); font-family: Arial, sans-serif; line-height: 1.6; border: 5px solid #3498db;">
# <h3 style="color: #3498db; font-size: 1.8em; margin-top: 30px;">Trend:</h3>
# <p>This represents the long-term movement of the time series. For example, when you review the sales of a company over the years, you might observe a trend of increasing or decreasing sales. The trend typically changes in a linear or non-linear manner over time.</p>
# </div>

# %% [markdown]
# ![Trend.png](attachment:a770386f-db1d-4446-9fd4-e7afa8d5d704.png)

# %% [markdown]
# <div style="background-color: #f4f4f4; padding: 20px; border-radius: 20px; box-shadow: 0 0 25px rgba(0,0,0,0.1); font-family: Arial, sans-serif; line-height: 1.6; border: 5px solid #3498db;">
# <h3 style="color: #3498db; font-size: 1.8em; margin-top: 30px;">Seasonality:</h3>
# <p>This refers to short-term fluctuations in the time series that repeat at specific intervals. For instance, during certain months of the year (e.g., summer vacation or winter season), a tourism company might observe spikes in their revenue. Seasonality is generally a component with a known and fixed period.</p>
# </div>

# %% [markdown]
# ![Seasonality.png](attachment:e8b03450-5111-4cb9-b05f-f20aa3fc5468.png)

# %% [markdown]
# <div style="background-color: #f4f4f4; padding: 20px; border-radius: 20px; box-shadow: 0 0 25px rgba(0,0,0,0.1); font-family: Arial, sans-serif; line-height: 1.6; border: 5px solid #3498db;">
# <h3 style="color: #3498db; font-size: 1.8em; margin-top: 30px;">Cycle:</h3>
# <p>This denotes long-term oscillations and is usually associated with economic cycles. Cycles differ from seasonality since they typically do not have a known fixed period. For example, fluctuations might be observed between periods of economic expansion and contraction.</p>
# </div>

# %% [markdown]
# ![Cycle.png](attachment:733f72e0-1657-4e34-92c9-988d49dd70d9.png)

# %% [markdown]
# <div style="background-color: #f4f4f4; padding: 20px; border-radius: 20px; box-shadow: 0 0 25px rgba(0,0,0,0.1); font-family: Arial, sans-serif; line-height: 1.6; border: 5px solid #3498db;">
# <h3 style="color: #3498db; font-size: 1.8em; margin-top: 30px;">Randomness (Error or Noise):</h3>
# <p>This component represents random fluctuations that are not explained by the other three components. Randomness in the time series is unforeseen oscillations and is often termed "noise." Randomness is generally a component challenging to model or predict since it results from unforeseen events.</p>
# </div>

# %% [markdown]
# ![Randomness()Noise).png](attachment:ce4a6bf1-9dce-4648-ab70-820565c2124f.png)

# %% [markdown]
# <div style="background-color: #f4f4f4; padding: 20px; border-radius: 20px; box-shadow: 0 0 25px rgba(0,0,0,0.1); font-family: Arial, sans-serif; line-height: 1.6; border: 5px solid #3498db

# %% [markdown]
# <div style="background-color: #eaf6f9; padding: 50px; border-radius: 25px; box-shadow: 0 0 20px rgba(0,0,0,0.05); font-family: 'Verdana', sans-serif; line-height: 1.7; border: 4px solid #d5eaf0;">
#
# <h2 style="text-align: center; color: #1e272e; font-size: 2.1em; border-bottom: 3px dashed #3498db; padding-bottom: 12px; margin-bottom: 35px;">📊 Dive into Time Series: Statistical Methods</h2>
#
# <section style="background-color: #d6eaf8; padding: 25px; border-radius: 20px; margin-bottom: 20px;">
#     <h3 style="color: #c0392b; font-size: 1.75em; margin-top: 0; font-weight: 500;">AR (Auto-Regressive Model)</h3>
#     <p>Characterized by its reliance on past values, the AR model is tailored for stationary series without trends or seasonality.</p>
#     <p>The model equation:</p>
#     <p>\[ X_t = c + \phi_1 X_{t-1} + \phi_2 X_{t-2} + \dots + \phi_p X_{t-p} + \varepsilon_t \]</p>
# </section>
#
# <section style="background-color: #d6eaf8; padding: 25px; border-radius: 20px; margin-bottom: 20px;">
#     <h3 style="color: #d35400; font-size: 1.75em; margin-top: 0; font-weight: 500;">MA (Moving Average Model)</h3>
#     <p>The MA model is influenced by past white noise or random shocks, offering a unique perspective on time series analysis.</p>
#     <p>The model equation:</p>
#     <p>\[ X_t = \mu + \varepsilon_t + \theta_1 \varepsilon_{t-1} + \dots + \theta_q \varepsilon_{t-q} \]</p>
# </section>
#
# <section style="background-color: #d6eaf8; padding: 25px; border-radius: 20px; margin-bottom: 20px;">
#     <h3 style="color: #8e44ad; font-size: 1.75em; margin-top: 0; font-weight: 500;">ARMA (Auto-Regressive Moving Average Model)</h3>
#     <p>Blending the essence of both AR and MA, the ARMA model introduces a versatile approach to time series forecasting.</p>
#     <p>The model equation:</p>
#     <p>\[ X_t = c + \phi_1 X_{t-1} + \dots + \phi_p X_{t-p} + \varepsilon_t + \theta_1 \varepsilon_{t-1} + \dots + \theta_q \varepsilon_{t-q} \]</p>
# </section>
#
# <section style="background-color: #d6eaf8; padding: 25px; border-radius: 20px; margin-bottom: 20px;">
#     <h3 style="color: #27ae60; font-size: 1.75em; margin-top: 0; font-weight: 500;">ARIMA (Auto-Regressive Integrated Moving Average Model)</h3>
#     <p>ARIMA is a refined variant of ARMA, integrating differencing to achieve stationarity in the time series data.</p>
#     <p>ARIMA is denoted as ARIMA(p, d, q), where:</p>
#     <ul>
#         <li>\( p \) represents the lags for the AR model.</li>
#         <li>\( d \) indicates the differencing steps.</li>
#         <li>\( q \) specifies the lags for the MA model.</li>
#     </ul>
# </section>
#
# <section style="background-color: #d6eaf8; padding: 25px; border-radius: 20px;">
#     <h3 style="color: #2980b9; font-size: 1.75em; margin-top: 0; font-weight: 500;">SARIMA (Seasonal Auto-Regressive Integrated Moving Average Model)</h3>
#     <p>Expanding on ARIMA, SARIMA focuses on seasonal patterns in data.</p>
#     <p>SARIMA is represented as SARIMA(p, d, q)(P, D, Q)[s], where:</p>
#     <ul>
#         <li>\( p, d, q \) are the parameters for ARIMA.</li>
#         <li>\( P, D, Q \) denote the seasonal components.</li>
#         <li>\( s \) is the seasonal period.</li>
#     </ul>
# </section>
#
# </div>

# %% [markdown]
# <div style="background-color: #e5edf2; padding: 50px; border-radius: 30px; box-shadow: 0 0 30px rgba(0,0,0,0.1); font-family: 'Georgia', serif; line-height: 1.7; border: 4px solid #a5b7d0;">
#
# <h2 style="text-align: center; color: #34495e; font-size: 2.5em; border-bottom: 3px solid #3498db; padding-bottom: 15px; margin-bottom: 35px;">Business Problem</h2>
#
# <p style="font-size: 1.3em; color: #2c3e50; margin-top: 20px; text-align: justify;">For airline companies to effectively conduct operational and financial planning, it is imperative to accurately forecast future passenger demand. Predicting future airline passenger demand based on historical data can assist companies in utilizing their resources more efficiently, increasing their revenues, and minimizing costs. This study aims to use time series analysis techniques to predict future passenger numbers, leveraging a dataset that captures monthly total airline passenger counts starting from 1949.</p>
#
# </div>

# %% [markdown]
# <div style="border: 10px solid #3498db; border-radius: 30px; padding: 40px; box-shadow: 10px 10px 25px #2980b9; background: linear-gradient(to bottom right, #D6EAF8, #EBF5FB);">
#     <h2 style="font-size: 34px; font-weight: bold; color: #0E6655; text-align: center; border-bottom: 5px solid #F1C40F; font-family: 'Arial'; padding: 20px; margin-top: 0; box-shadow: 5px 5px 15px #7D8A99; background-color: #FEF5E7; border-radius: 20px;">📊 Dataset Story</h2>
#     <ul style="font-size: 18px; font-family: 'Calibri'; padding: 30px; line-height: 1.7; list-style-type: none;">
#         <li>📌 <strong style="color: #0E6655;">Dataset Origin:</strong> The dataset captures the monthly total airline passenger counts starting from 1949.</li>
#         <li>🔢 <strong style="color: #0E6655;">Total Observations:</strong> There are 144 monthly observations in the dataset.</li>
#         <li>🌆 <strong style="color: #0E6655;">Average Monthly Passengers:</strong> On average, there are about 280 passengers monthly.</li>
#         <li>📈 <strong style="color: #0E6655;">Highest Monthly Count:</strong> The highest monthly passenger count observed is 622.</li>
#         <li>📉 <strong style="color: #0E6655;">Lowest Monthly Count:</strong> The lowest monthly passenger count observed is 104.</li>
#         <li>🔍 <strong style="color: #0E6655;">Importance:</strong> Forecasting passenger counts is essential for airline companies to effectively conduct operational and financial planning.</li>
#     </ul>
# </div>

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:75%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>1 |</span></b> <b>Importing Libraries</b></div>

# %%
import itertools
import warnings
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import statsmodels.api as sm
import statsmodels.tsa.api as smt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error
from IPython.display import HTML as html_print
from termcolor import colored
from IPython.display import display
warnings.filterwarnings('ignore')

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:75%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>2 |</span></b> <b>Adjusting Row & Column Settings</b></div>

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:75%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>3 |</span></b> <b>Loading The Data Set</b></div>

# %%
df = pd.read_csv('/kaggle/input/airlinepassengers/airline-passengers.csv', index_col='month', parse_dates=True)

# %%
df.head()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:75%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>4 |</span></b> <b>Exploratory Data Analysis</b></div>

# %%
def print_section_title(title):
    print(colored(title, 'blue', attrs=['bold', 'underline']))
    
def display_head_and_tail(dataframe, head=5):
    display(dataframe.head(head).style.set_caption("Head"))
    display(dataframe.tail(head).style.set_caption("Tail"))

def display_na(dataframe):
    na_df = dataframe.isnull().sum().reset_index()
    na_df.columns = ['Column', 'Number of NA']
    display(na_df.style.set_caption("Number of NA Values"))

def display_quantiles(dataframe):
    quantiles_df = dataframe.describe([0, 0.05, 0.50, 0.95, 0.99, 1]).T
    display(quantiles_df.style.format("{:.2f}").set_caption("Quantiles"))

def check_df(dataframe, head=5):
    print_section_title('Shape')
    print(dataframe.shape)
    print_section_title('Types')
    print(dataframe.dtypes.to_frame('Data Type').style.set_caption("Data Types"))
    print_section_title('Info')
    print(dataframe.info())
    print_section_title('Head & Tail')
    display_head_and_tail(dataframe, head)
    print_section_title('NA Values')
    display_na(dataframe)
    print_section_title('Quantiles')
    display_quantiles(dataframe)

# %%
check_df(df)

# %%
df.shape

# %%
df[['total_passengers']].plot(title='Passengers Data')

# %%
df.index.freq = "MS"

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:75%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>5 |</span></b> <b>Holdout</b></div>

# %%
train = df[:120]

# %%
len(train)

# %%
test = df[120:]

# %%
len(test)

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:75%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>6 |</span></b> <b>Single Exponential Smoothing</b></div>

# %%
def ses_optimizer(train, alphas, step=48):
    best_alpha, best_mae = None, float("inf")
    for alpha in alphas:
        ses_model = SimpleExpSmoothing(train).fit(smoothing_level=alpha)
        y_pred = ses_model.forecast(step)
        mae = mean_absolute_error(test, y_pred)
        if mae < best_mae:
            best_alpha, best_mae = alpha, mae
        print("alpha:", round(alpha, 2), "mae:", round(mae, 4))
    print("best_alpha:", round(best_alpha, 2), "best_mae:", round(best_mae, 4))
    return best_alpha, best_mae

# %%
alphas = np.arange(0.01, 1, 0.10)

# %%
best_alpha, best_mae = ses_optimizer(train, alphas, step=24)

# %%
ses_model = SimpleExpSmoothing(train).fit(smoothing_level=best_alpha)

# %%
y_pred = ses_model.forecast(24)

# %%
y_pred

# %%
def plot_prediction(y_pred, label):
    train["total_passengers"].plot(legend=True, label="TRAIN")
    test["total_passengers"].plot(legend=True, label="TEST")
    y_pred.plot(legend=True, label="PREDICTION")
    plt.title("Train, Test and Predicted Test Using "+label)
    plt.show(block=True)

# %%
plot_prediction(y_pred, "Single Exponential Smoothing")

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:75%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>7 |</span></b> <b>Double Exponential Smoothing</b></div>

# %%
def des_optimizer(train, alphas, betas, step=48):
    best_alpha, best_beta, best_mae = None, None, float("inf")
    for alpha in alphas:
        for beta in betas:
            des_model = ExponentialSmoothing(train, trend="add").fit(smoothing_level=alpha, smoothing_slope=beta)
            y_pred = des_model.forecast(step)
            mae = mean_absolute_error(test, y_pred)
            if mae < best_mae:
                best_alpha, best_beta, best_mae = alpha, beta, mae
            print("alpha:", round(alpha, 2), "beta:", round(beta, 2), "mae:", round(mae, 4))
    print("best_alpha:", round(best_alpha, 2), "best_beta:", round(best_beta, 2), "best_mae:", round(best_mae, 4))
    return best_alpha, best_beta, best_mae

# %%
alphas = np.arange(0.01, 1, 0.10)

# %%
betas = np.arange(0.01, 1, 0.10)

# %%
best_alpha, best_beta, best_mae = des_optimizer(train, alphas, betas, step=24)

# %%
des_model = ExponentialSmoothing(train, trend="add").fit(smoothing_level=best_alpha,
                                                         smoothing_slope=best_beta)

# %%
y_pred = des_model.forecast(24)

# %%
y_pred

# %%
plot_prediction(y_pred, "Double Exponential Smoothing")

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:75%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>8 |</span></b> <b>Triple Exponential Smoothing (Holt-Winters)</b></div>

# %%
def tes_optimizer(train, abg, step=48):
    best_alpha, best_beta, best_gamma, best_mae = None, None, None, float("inf")
    for comb in abg:
        tes_model = ExponentialSmoothing(train, trend="add", seasonal="add", seasonal_periods=12).\
            fit(smoothing_level=comb[0], smoothing_slope=comb[1], smoothing_seasonal=comb[2])
        y_pred = tes_model.forecast(step)
        mae = mean_absolute_error(test, y_pred)
        if mae < best_mae:
            best_alpha, best_beta, best_gamma, best_mae = comb[0], comb[1], comb[2], mae
        print([round(comb[0], 2), round(comb[1], 2), round(comb[2], 2), round(mae, 2)])

    print("best_alpha:", round(best_alpha, 2), "best_beta:", round(best_beta, 2), "best_gamma:", round(best_gamma, 2),
          "best_mae:", round(best_mae, 4))

    return best_alpha, best_beta, best_gamma, best_mae

# %%
alphas = betas = gammas = np.arange(0.10, 1, 0.20)

# %%
abg = list(itertools.product(alphas, betas, gammas))

# %%
best_alpha, best_beta, best_gamma, best_mae = tes_optimizer(train, abg, step=24)

# %%
tes_model = ExponentialSmoothing(train, trend="mul", seasonal="mul", seasonal_periods=12).\
            fit(smoothing_level=best_alpha, smoothing_slope=best_beta, smoothing_seasonal=best_gamma)

# %%
y_pred = tes_model.forecast(24)

# %%
plot_prediction(y_pred, "Triple Exponential Smoothing ADD")

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:75%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>9 |</span></b> <b>ARIMA(p, d, q): (Autoregressive Integrated Moving Average)</b></div>

# %%
p = d = q = range(0, 4)

# %%
pdq = list(itertools.product(p, d, q))

# %%
def arima_optimizer_aic(train, orders):
    best_aic, best_params = float("inf"), None
    for order in orders:
        try:
            arma_model_result = ARIMA(train, order).fit(disp=0)
            aic = arma_model_result.aic
            if aic < best_aic:
                best_aic, best_params = aic, order
            print('ARIMA%s AIC=%.2f' % (order, aic))
        except:
            continue
    print('Best ARIMA%s AIC=%.2f' % (best_params, best_aic))
    return best_params

# %%
best_params_aic = arima_optimizer_aic(train, pdq)

# %%
arima_model = ARIMA(train, best_params_aic).fit()

# %%
y_pred = arima_model.forecast(24)

# %%
y_pred

# %%
mean_absolute_error(test, y_pred)

# %%
plot_prediction(pd.Series(y_pred, index=test.index), "ARIMA")

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:75%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>10 |</span></b> <b>SARIMA(p, d, q): (Seasonal Autoregressive Integrated Moving-Average)</b></div>

# %%
p = d = q = range(0, 2)

# %%
pdq = list(itertools.product(p, d, q))

# %%
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %%
def sarima_optimizer_aic(train, pdq, seasonal_pdq):
    best_aic, best_order, best_seasonal_order = float("inf"), float("inf"), None
    for param in pdq:
        for param_seasonal in seasonal_pdq:
            try:
                sarimax_model = SARIMAX(train, order=param, seasonal_order=param_seasonal)
                results = sarimax_model.fit(disp=0)
                aic = results.aic
                if aic < best_aic:
                    best_aic, best_order, best_seasonal_order = aic, param, param_seasonal
                print('SARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, aic))
            except:
                continue
    print('SARIMA{}x{}12 - AIC:{}'.format(best_order, best_seasonal_order, best_aic))
    return best_order, best_seasonal_order

# %%
best_order, best_seasonal_order = sarima_optimizer_aic(train, pdq, seasonal_pdq)

# %%
model = SARIMAX(train, order=best_order, seasonal_order=best_seasonal_order)

# %%
sarima_final_model = model.fit(disp=0)

# %%
y_pred_test = sarima_final_model.get_forecast(steps=24)

# %%
y_pred_test

# %%
y_pred = y_pred_test.predicted_mean

# %%
y_pred

# %%
mean_absolute_error(test, y_pred)

# %%
plot_prediction(pd.Series(y_pred, index=test.index), "SARIMA")

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:75%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>11 |</span></b> <b>SARIMA Optimization Based on MAE</b></div>

# %%
p = d = q = range(0, 2)

# %%
pdq = list(itertools.product(p, d, q))

# %%
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %%
def sarima_optimizer_mae(train, pdq, seasonal_pdq):
    best_mae, best_order, best_seasonal_order = float("inf"), float("inf"), None

    for param in pdq:
        for param_seasonal in seasonal_pdq:
            try:
                model = SARIMAX(train, order=param, seasonal_order=param_seasonal)
                sarima_model = model.fit(disp=0)
                y_pred_test = sarima_model.get_forecast(steps=24)
                y_pred = y_pred_test.predicted_mean
                mae = mean_absolute_error(test, y_pred)

                # mae = fit_model_sarima(train, val, param, param_seasonal)

                if mae < best_mae:
                    best_mae, best_order, best_seasonal_order = mae, param, param_seasonal
                print('SARIMA{}x{}12 - MAE:{}'.format(param, param_seasonal, mae))
            except:
                continue
    print('SARIMA{}x{}12 - MAE:{}'.format(best_order, best_seasonal_order, best_mae))
    return best_order, best_seasonal_order

# %%
best_order, best_seasonal_order = sarima_optimizer_mae(train, pdq, seasonal_pdq)

# %%
model = SARIMAX(train, order=best_order, seasonal_order=best_seasonal_order)

# %%
sarima_final_model = model.fit(disp=0)

# %%
y_pred_test = sarima_final_model.get_forecast(steps=24)

# %%
y_pred_test

# %%
y_pred = y_pred_test.predicted_mean

# %%
y_pred

# %%
mean_absolute_error(test, y_pred)

# %%
plot_prediction(pd.Series(y_pred, index=test.index), "SARIMA")

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:75%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>12 |</span></b> <b>Final Model</b></div>

# %% [markdown]
# | Model | Parametreler | MAE |
# |-------|--------------|-----|
# | SES | \(\alpha = 0.11\) | 82.528 |
# | DES | \(\alpha = 0.01, \beta = 0.11\) | 54.1036 |
# | TES | \(\alpha = 0.3, \beta = 0.3, \gamma = 0.5\) | 11.9947 |
# | ARIMA | - | 206.3417 |
# | SARIMA | - | 68.5773 |
# | SARIMA (Optimized) | Based on MAE | 30.6262 |

# %% [markdown]
# <style>
#     .info-box {
#         padding: 20px 30px;
#         margin: 20px;
#         border-radius: 10px;
#         box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1);
#         background-color: #f7f9fc;
#         border-left: 5px solid #4CAF50;
#         font-size: 18px;
#     }
# </style>
#
# <div class="info-box">
#     This table assists you in comparing the MAE (Mean Absolute Error) values of different time series models. Generally, the model with the lowest MAE value exhibits the best performance. In this case, the TES model has a significantly lower MAE value compared to other models, indicating that it performs best for this dataset. Therefore, the TES model was re-established using ALL DATA as the Final Model to make predictions.
# </div>

# %%
tes_model_final = ExponentialSmoothing(df, trend="add", seasonal="add", seasonal_periods=12).\
            fit(smoothing_level=best_alpha, smoothing_slope=best_beta, smoothing_seasonal=best_gamma)

# %%
tes_model_final.forecast(6)
